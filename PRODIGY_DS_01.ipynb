# %% [markdown]
# # Bhrugu Potdar
# # Task 1 :- Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.
# # Prodigy infotech

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Generating sample data with age and gender
np.random.seed(0)
ages = np.random.randint(18, 80, size=10000)  # 100x larger dataset
genders = np.random.choice(['Male', 'Female'], size=10000)

# Generating sample data with age and gender
np.random.seed(0)
ages = np.random.randint(18, 80, size=10000)  # 100x larger dataset
genders = np.random.choice(['Male', 'Female'], size=10000)
# Plotting histogram for ages
plt.figure(figsize=(10, 6))
plt.hist(data['Age'], bins=20, color='skyblue', edgecolor='black')

# Adding labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Ages')

# Displaying the histogram
plt.show()

# Plotting bar chart for genders
plt.figure(figsize=(6, 4))
data['Gender'].value_counts().plot(kind='bar', color=['skyblue', 'pink'])

# Adding labels and title
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution of Genders')

# Displaying the bar chart
plt.show()
